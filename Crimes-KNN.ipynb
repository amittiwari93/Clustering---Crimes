# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_csv('crime_data.csv')

# %%
dataset.shape
# Out:
# (50, 5)

# %%
dataset
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %% [markdown]
# ### Data Cleaning

# %%
dataset=dataset.drop(['Unnamed: 0'],axis=1)
dataset
# Out:
#     Murder  Assault  UrbanPop  Rape
# 0     13.2      236        58  21.2
# 1     10.0      263        48  44.5
# 2      8.1      294        80  31.0
# 3      8.8      190        50  19.5
# 4      9.0      276        91  40.6
# 5      7.9      204        78  38.7
# 6      3.3      110        77  11.1
# 7      5.9      238        72  15.8
# 8     15.4      335        80  31.9
# 9     17.4      211        60  25.8
# 10     5.3       46        83  20.2
# 11     2.6      120        54  14.2
# 12    10.4      249        83  24.0
# 13     7.2      113        65  21.0
# 14     2.2       56        57  11.3
# 15     6.0      115        66  18.0
# 16     9.7      109        52  16.3
# 17    15.4      249        66  22.2
# 18     2.1       83        51   7.8
# 19    11.3      300        67  27.8
# 20     4.4      149        85  16.3
# 21    12.1      255        74  35.1
# 22     2.7       72        66  14.9
# 23    16.1      259        44  17.1
# 24     9.0      178        70  28.2
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Murder    50 non-null     float64
#  1   Assault   50 non-null     int64
#  2   UrbanPop  50 non-null     int64
#  3   Rape      50 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 1.7 KB

# %% [markdown]
# ### Scaling the features to common scale

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
dataset_norm=sc.fit_transform(dataset)

# %%
print(dataset_norm)
# Out:
# [[ 1.25517927  0.79078716 -0.52619514 -0.00345116]
#  [ 0.51301858  1.11805959 -1.22406668  2.50942392]
#  [ 0.07236067  1.49381682  1.00912225  1.05346626]
#  [ 0.23470832  0.23321191 -1.08449238 -0.18679398]
#  [ 0.28109336  1.2756352   1.77678094  2.08881393]
#  [ 0.02597562  0.40290872  0.86954794  1.88390137]
#  [-1.04088037 -0.73648418  0.79976079 -1.09272319]
#  [-0.43787481  0.81502956  0.45082502 -0.58583422]
#  [ 1.76541475  1.99078607  1.00912225  1.1505301 ]
#  [ 2.22926518  0.48775713 -0.38662083  0.49265293]
#  [-0.57702994 -1.51224105  1.21848371 -0.11129987]
#  [-1.20322802 -0.61527217 -0.80534376 -0.75839217]
#  [ 0.60578867  0.94836277  1.21848371  0.29852525]
#  [-0.13637203 -0.70012057 -0.03768506 -0.0250209 ]
#  [-1.29599811 -1.39102904 -0.5959823  -1.07115345]
#  [-0.41468229 -0.67587817  0.03210209 -0.34856705]
#  [ 0.44344101 -0.74860538 -0.94491807 -0.53190987]
#  [ 1.76541475  0.94836277  0.03210209  0.10439756]
# ...

# %% [markdown]
# ### Using Elbow Method

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(dataset_norm)
    wcss.append(kmeans.inertia_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ### Training the K-Means

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit(dataset_norm)

# %%
y_kmeans
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
kmeans.labels_
# Out:
# array([3, 1, 1, 2, 1, 1, 0, 0, 1, 3, 0, 4, 1, 2, 4, 2, 2, 3, 4, 1, 0, 1,
#        4, 3, 1, 2, 2, 1, 4, 0, 1, 1, 3, 4, 0, 2, 0, 0, 0, 3, 4, 3, 1, 0,
#        4, 2, 0, 4, 4, 2])

# %% [markdown]
# ### Assign Cluster id to equivalent row data

# %%
dataset_2=dataset.copy()
dataset_2['Cluster_Id']=kmeans.labels_
dataset_2
# Out:
#     Murder  Assault  UrbanPop  Rape  Cluster_Id
# 0     13.2      236        58  21.2           3
# 1     10.0      263        48  44.5           1
# 2      8.1      294        80  31.0           1
# 3      8.8      190        50  19.5           2
# 4      9.0      276        91  40.6           1
# 5      7.9      204        78  38.7           1
# 6      3.3      110        77  11.1           0
# 7      5.9      238        72  15.8           0
# 8     15.4      335        80  31.9           1
# 9     17.4      211        60  25.8           3
# 10     5.3       46        83  20.2           0
# 11     2.6      120        54  14.2           4
# 12    10.4      249        83  24.0           1
# 13     7.2      113        65  21.0           2
# 14     2.2       56        57  11.3           4
# 15     6.0      115        66  18.0           2
# 16     9.7      109        52  16.3           2
# 17    15.4      249        66  22.2           3
# 18     2.1       83        51   7.8           4
# ...

# %% [markdown]
# ### Finding Centeroids

# %%
y_kmeans.cluster_centers_
# Out:
# array([[-0.63817386, -0.38827513,  0.88223651, -0.27797516],
#        [ 0.70212683,  1.04999438,  0.72997363,  1.28990383],
#        [-0.15956455, -0.44557535, -0.39437496, -0.32460067],
#        [ 1.59644066,  0.97606837, -0.78540457,  0.0489325 ],
#        [-1.18467401, -1.2201201 , -1.01470522, -1.11321445]])

# %%
dataset_2.groupby('Cluster_Id').agg(['mean']).reset_index()
# Out:
#   Cluster_Id     Murder     Assault   UrbanPop       Rape
#                    mean        mean       mean       mean
# 0          0   5.036364  138.727273  78.181818  18.654545
# 1          1  10.815385  257.384615  76.000000  33.192308
# 2          2   7.100000  134.000000  59.888889  18.222222
# 3          3  14.671429  251.285714  54.285714  21.685714
# 4          4   2.680000   70.100000  51.000000  10.910000

# %% [markdown]
# ### Plotting Clusters

# %%
plt.figure(figsize=(10,7))
plt.scatter(dataset_2['Cluster_Id'],dataset_2['Murder'],c=kmeans.labels_)

# %%
plt.scatter(dataset_2['Cluster_Id'],dataset_2['Assault'],c=kmeans.labels_)

# %%
plt.scatter(dataset_2['Cluster_Id'],dataset_2['UrbanPop'],c=kmeans.labels_)

# %%
plt.scatter(dataset_2['Cluster_Id'],dataset_2['Rape'],c=kmeans.labels_)
